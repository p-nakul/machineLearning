# %% [markdown]
# # Simple Linear regression model example on Diabetes dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
#Load diabetes dataset
X, y = datasets.load_diabetes(return_X_y=True)

# %%
# View data
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
## View two samples
X[:2]
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187239, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, -0.02632753, -0.00844872,
#         -0.01916334,  0.07441156, -0.03949338, -0.06833155, -0.09220405]])

# %%
# Take only zeroth feature per sample
X = X[:, np.newaxis, 0]

# %%
X[:2]
# Out:
# array([[ 0.03807591],
#        [-0.00188202]])

# %%
X.shape
# Out:
# (442, 1)

# %%
plt.scatter(X,y, color = "blue")

# %%
# Divide into training and test data
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, test_size = 0.3)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (309, 1)
# (133, 1)

# %%
plt.scatter(X_train, y_train, color = "blue")
plt.scatter(X_test, y_test, color = "red")

# %%
# Create instance of model
lr = linear_model.LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
plt.plot(X_test, y_pred, color = "black")
plt.scatter(X_train, y_train, color = "blue")
plt.scatter(X_test, y_test, color = "red")

# %%
from sklearn import metrics
accuracy = metrics.r2_score(y_test, y_pred)
MAE = metrics.mean_absolute_error(y_test, y_pred)
MSE = metrics.mean_squared_error(y_test, y_pred)
print(" Linear Regression Model Accuracy = ", accuracy*100, "%")
print("Mean Absolute Error = ", MAE)
print("Mean Squared Error = ", MSE)
# Out:
#  Linear Regression Model Accuracy =  0.7504871049609285 %
# Mean Absolute Error =  59.992645301474276
# Mean Squared Error =  4996.6860636565925
